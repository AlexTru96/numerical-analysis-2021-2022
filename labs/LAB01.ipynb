# %%
a = [123, "sad", 3.43]

# %%
a
# Out:
# [123, 'sad', 3.43]

# %%
print(len(a))
# Out:
# 3

# %%
a[0]=1234

# %%
print(a)
# Out:
# [1234, 'sad', 3.43]

# %%
d = {"marco", 12 ,34 , 34 ,232}

# %%
print(d)
# Out:
# {232, 34, 12, 'marco'}

# %%
from math import cos,pi
a = cos (2*pi)
print(a)
# Out:
# 1.0

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/alex/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['cos', 'pi']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
import math

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
x=range(10,100)
print(x)
# Out:
# range(10, 100)

# %%
y=[]
for i in x:
    y.append(cos(i))

# %%
plot(x,y)

# %%
dx = 0.05
N=100
x = [dx*i for i in range(N)]
y = [cos(pi*p) for p in x]
plot(x,y)
